# %%
from astropy.io import ascii
from cxotime import CxoTime

# %%
ace_table = ascii.read('/data/mta4/Space_Weather/ACE/Data/ace_12h_archive')

# %%
ace_table
# Out:
# <Table length=267>
#  col1  col2  col3  col4  col5  col6 ...  col12   col13   col14   col15   col16
# int64 int64 int64 int64 int64 int64 ... float64 float64 float64 float64 float64
# ----- ----- ----- ----- ----- ----- ... ------- ------- ------- ------- -------
#  2026     3     6   505 61105 18300 ...    33.9    1.86   0.355  0.0543    -1.0
#  2026     3     6   505 61105 18300 ...    33.9    1.86   0.355  0.0543    -1.0
#  2026     3     6   510 61105 18600 ...    44.4    1.83   0.309  0.0624    -1.0
#  2026     3     6   510 61105 18600 ...    44.4    1.83   0.309  0.0624    -1.0
#  2026     3     6   515 61105 18900 ...    75.5    3.06   0.258   0.126    -1.0
#  2026     3     6   515 61105 18900 ...    75.5    3.06   0.258   0.126    -1.0
#  2026     3     6   520 61105 19200 ...    59.0    2.83   0.332  0.0964    -1.0
#  2026     3     6   520 61105 19200 ...    59.0    2.83   0.332  0.0964    -1.0
#  2026     3     6   525 61105 19500 ...    56.1    1.98   0.407   0.121    -1.0
#   ...   ...   ...   ...   ...   ... ...     ...     ...     ...     ...     ...
#  2026     3     6  1620 61105 58800 ...    32.7    1.47   0.314   0.126    -1.0
#  2026     3     6  1625 61105 59100 ...    34.3    1.73   0.458  0.0873    -1.0
#  2026     3     6  1630 61105 59400 ...    33.1    1.55   0.323  0.0662    -1.0
#  2026     3     6  1635 61105 59700 ...    36.6    1.88    0.24  0.0778    -1.0
#  2026     3     6  1640 61105 60000 ...    28.9    1.88   0.339    0.14    -1.0
#  2026     3     6  1645 61105 60300 ...    31.9    1.72   0.364  0.0867    -1.0
#  2026     3     6  1650 61105 60600 ...    43.6    1.94   0.321  0.0321    -1.0
#  2026     3     6  1655 61105 60900 ...    38.3    1.84    0.37   0.127    -1.0
#  2026     3     6  1700 61105 61200 ...    37.4    1.83   0.384  0.0714    -1.0
#  2026     3     6  1705 61105 61500 ...    42.5    1.26   0.589   0.062    -1.0

# %% [markdown]
# # Write test set for ACE invalid data alert

# %%
ace_table['col10'] = -1 #: Change all proton status to -1

# %%
filename = "test_invalid_ace_12h_archive"
ascii.write(ace_table, filename, format='no_header', delimiter=' ', overwrite=True)

# %% [markdown]
# # Write test set for ACE P3 alert

# %%
#: This rewrites the entire column. The alert only scans the last two hours.
ace_table['col12'] = 400000

# %%
filename = "test_p3_ace_12h_archive"
ascii.write(ace_table, filename, format='no_header', delimiter=' ', overwrite=True)
